# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 6.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ADJ, ADP, AUX, DET, NOUN, NUM, PROPN, PUNCT, SCONJ, VERB

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

text = ("The cat sat on the couch"
        "Time flies like an arrow"
        "The spy saw the cop with the telescope"
        "The spy saw the cop with the revolver"
        )
doc = nlp(text)

print("Noun Phrases: ", [chunk.text for chunk in doc.noun_chunks])
# Out:
# Noun Phrases:  ['The cat', 'the couchTime flies', 'an arrowThe spy', 'the cop', 'the telescopeThe spy', 'the cop', 'the revolver']
