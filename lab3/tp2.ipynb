# %% [markdown]
# ### `CNN Classification`

# %%
# Out:
# usage: ipykernel_launcher.py [-h] [--model MODEL] --train TRAIN --valid VALID
#                              --test TEST [--epochs EPOCHS]
# ipykernel_launcher.py: error: the following arguments are required: --train, --valid, --test
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /Users/idrissamahamoudoudicko/anaconda3/envs/HandonNLP/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
